# %% [markdown]
# 본 코드는 colab에서 구동 확인 함
# - 로컬에서 안 되는 예제

# %%
# 환경 설정
# !pip install git+https://github.com/autodistill/autodistill-grounded-sam-2 rf_groundingdino -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 80.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 21.1 MB/s eta 0:00:00
#   Building wheel for autodistill_grounded_sam_2 (setup.py) ... done
#   Building wheel for flash-attn (setup.py) ... done

# %%
# 테스트 데이터 수집
# !wget https://media.roboflow.com/containers.zip
# !unzip containers.zip
# Out:
# --2024-11-21 09:58:08--  https://media.roboflow.com/containers.zip
# Resolving media.roboflow.com (media.roboflow.com)... 34.110.133.209
# Connecting to media.roboflow.com (media.roboflow.com)|34.110.133.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12356763 (12M) [application/zip]
# Saving to: ‘containers.zip’
#
# containers.zip      100%[===================>]  11.78M  7.34MB/s    in 1.6s
#
# 2024-11-21 09:58:10 (7.34 MB/s) - ‘containers.zip’ saved [12356763/12356763]
#
# Archive:  containers.zip
#    creating: containers/
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-75_jpg.rf.ffbb8716eb886f91e3a561e2ba4be074.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-75_jpg.rf.ffbb8716eb886f91e3a561e2ba4be074.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-169_jpg.rf.c0bf90f4b4bf5450508f6ccd5fd85e79.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-169_jpg.rf.c0bf90f4b4bf5450508f6ccd5fd85e79.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-181_jpg.rf.1598c93a8f061325120aec7024058020.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-181_jpg.rf.1598c93a8f061325120aec7024058020.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-188_jpg.rf.26e14b83a230099570d27f59e7fb6cff.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-188_jpg.rf.26e14b83a230099570d27f59e7fb6cff.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-142_jpg.rf.a3eb3346201af92d3435edde3edc5075.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-142_jpg.rf.a3eb3346201af92d3435edde3edc5075.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-22_jpg.rf.7f68cb90d22c14dc1cc7bf3c664041c1.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-22_jpg.rf.7f68cb90d22c14dc1cc7bf3c664041c1.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-94_jpg.rf.5a62817c3d197a47027c366ac3c1e22f.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-94_jpg.rf.5a62817c3d197a47027c366ac3c1e22f.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-149_jpg.rf.72cfe0ba0bfdd636a9fcac7757673bac.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-149_jpg.rf.72cfe0ba0bfdd636a9fcac7757673bac.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-48_jpg.rf.fe4ed014091081a7fbd592701838d8ce.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-48_jpg.rf.fe4ed014091081a7fbd592701838d8ce.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-208_jpg.rf.18778ff1f2ad5e6f063e361f272dafe8.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-208_jpg.rf.18778ff1f2ad5e6f063e361f272dafe8.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-206_jpg.rf.f77c07ea4842a99baf7a29c6cc3de439.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-206_jpg.rf.f77c07ea4842a99baf7a29c6cc3de439.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-16_jpg.rf.493c556e1a31a48088e07f32684edae0.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-16_jpg.rf.493c556e1a31a48088e07f32684edae0.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-51_jpg.rf.17b6f24b2296680e81ff1b890da77f7b.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-51_jpg.rf.17b6f24b2296680e81ff1b890da77f7b.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-86_jpg.rf.0bbe6525bc04571fe3f595d61dd08181.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-86_jpg.rf.0bbe6525bc04571fe3f595d61dd08181.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-202_jpg.rf.58528bd572a0d0dc6bfd02e34edc1e6c.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-202_jpg.rf.58528bd572a0d0dc6bfd02e34edc1e6c.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4
jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-28_jpg.rf.4153b1a2fd47b28212fac8edd87434ca.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-10_jpg.rf.75a5875a4b8b4f8ce500dd53cf899d11.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-10_jpg.rf.75a5875a4b8b4f8ce500dd53cf899d11.jpg
#   inflating: containers/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-35_jpg.rf.789729e120dbe382a6be5537aaf52a1b.jpg
#   inflating: __MACOSX/containers/._Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-35_jpg.rf.789729e120dbe382a6be5537aaf52a1b.jpg

# %%
# SAM2 load
from autodistill_grounded_sam_2 import GroundedSAM2
# Out:
# Importing from timm.models.layers is deprecated, please import via timm.layers
# Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.

# %%
# 구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from autodistill.detection import CaptionOntology
from autodistill.utils import plot
import numpy as np
import cv2
import os
import random
import supervision as sv

# define an ontology to map class names to our Grounded SAM 2 prompt
# the ontology dictionary has the format {caption: class}
# where caption is the prompt sent to the base model, and class is the label that will
# be saved for that caption in the generated annotations
# then, load the model
base_model = GroundedSAM2(
    ontology=CaptionOntology(
        {
            "A traditional Korean soup made with beef, radish, kelp, green onions, soy sauce, salt, and other ingredients. It features a clear broth with beef and radish. Only the food in the bowl or pots": "Beef and radish soup"
        }
    ),
    model = "Grounding DINO",
    grounding_dino_box_threshold=0.33
)
# Out:
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased

# %%
# from autodistill.detection import CaptionOntology
# from autodistill.utils import plot
# import numpy as np
# import cv2
# import os
# import random
# import supervision as sv

# # define an ontology to map class names to our Grounded SAM 2 prompt
# # the ontology dictionary has the format {caption: class}
# # where caption is the prompt sent to the base model, and class is the label that will
# # be saved for that caption in the generated annotations
# # then, load the model
# base_model = GroundedSAM2(
#     ontology=CaptionOntology(
#         {
#             "shipping container": "container"
#         }
#     ),
#     model = "Grounding DINO",
#     grounding_dino_box_threshold=0.25
# )
# Out:
# trying to load grounding dino directly
# downloading dino model weights
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
# final text_encoder_type: bert-base-uncased
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
IMAGE_DIR = "/content/drive/MyDrive/Colab Notebooks/label_sample"
IMAGE_PATH = os.path.join(IMAGE_DIR, random.choice(os.listdir(IMAGE_DIR)))

results = base_model.predict(IMAGE_PATH).with_nms()
results = results[results.confidence > 0.1]

image = cv2.imread(IMAGE_PATH)

mask_annotator = sv.MaskAnnotator()

annotated_image = mask_annotator.annotate(
	image.copy(), detections=results
)

sv.plot_image(image=annotated_image, size=(8, 8))

# %%
base_model.label(IMAGE_DIR, extension="jpg")
# Out:
# Labeling /content/drive/MyDrive/Colab Notebooks/label_sample/04_041_04011007_160411268568628_0.jpg: 100%|██████████| 63/63 [00:53<00:00,  1.17it/s]
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160352776787939_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160352776787939_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160379082936745_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160379082936745_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160368064947536_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160368064947536_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160361112922654_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160361112922654_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160393089415288_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160393089415288_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160300082955220_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160300082955220_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160351058931010_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160351058931010_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160361112922654_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160361112922654_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160411268568628_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160411268568628_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160300082955220_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160300082955220_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160341514659261_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160341514659261_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160398829029651_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160398829029651_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160394131643782_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160394131643782_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160393089415288_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160393089415288_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160411268568628_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160411268568628_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160385409140820_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160385409140820_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160362503059408_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160362503059408_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160323328159354_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160323328159354_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160336354685639_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160336354685639_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160393979620013_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160393979620013_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160384754460005_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160384754460005_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160352776787939_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160352776787939_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160394131643782_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160394131643782_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160319283622212_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160319283622212_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160328983265281_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160328983265281_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160273723933160.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160273723933160.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160379480340929_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160379480340929_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160349970520007_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160349970520007_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160371612426231_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160371612426231_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160319283622212_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160319283622212_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160346630263055_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160346630263055_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160389151681181_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160389151681181_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160389151681181_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160389151681181_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160385409140820_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160385409140820_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160379082936745_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160379082936745_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160396988397027_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160396988397027_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160341661060821_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160341661060821_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160301123418375_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160301123418375_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160377547080157_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160377547080157_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images/04_041_04011007_160406424421257_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels/04_041_04011007_160406424421257_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/train/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/images/04_041_04011007_160367014953005_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/labels/04_041_04011007_160367014953005_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/images/04_041_04011007_160300339192517_1.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/labels/04_041_04011007_160300339192517_1.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/labels
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/images/04_041_04011007_160341514659261_0.jpg as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/images
# Found /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/labels/04_041_04011007_160341514659261_0.txt as already present, not moving anything to /content/drive/MyDrive/Colab Notebooks/label_sample_labeled/valid/labels
# Labeled dataset created - ready for distillation.

# %%
# import roboflow

# roboflow.login()

# rf = roboflow.Roboflow()

# workspace = rf.workspace("segmentation")
# workspace.upload_dataset(
#     IMAGE_DIR + "_labeled/",
#     "shipping-containers-kktus",
#     project_license="MIT",
#     project_type="Instance Segmentation",
# )
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Uploading to existing project segmentation/shipping-containers-kktus
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-11_jpg.rf.7c82c1ce169049910ff85313d65292a1.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-13_jpg.rf.65c3ac314ae8c53f04a0b6eacdb02ace.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-10_jpg.rf.75a5875a4b8b4f8ce500dd53cf899d11.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-12_jpg.rf.a897624f269bc94acbad8e666a403e6c.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-149_jpg.rf.72cfe0ba0bfdd636a9fcac7757673bac.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-150_jpg.rf.a9372ce0dc00bbb29a5c8755a92fabc0.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-145_jpg.rf.a341f79fb0bd03c1ffa4ce8a91286086.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-144_jpg.rf.d533310deecf4d54b9ac2696f155fea6.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-138_jpg.rf.68ea768966286da950f64460857d24de.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-147_jpg.rf.4bff07691220cccfde84178d3c6dd5ac.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-146_jpg.rf.3573b27e353553d7cb51a2e09ba08d6b.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-14_jpg.rf.d1644d2de92ea8eda199f776e271a57c.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-159_jpg.rf.7a6a445bb7295a9a84e208e4c2efa5b8.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-154_jpg.rf.c172fc03ceed1869bf7cb7837199f875.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-15_jpg.rf.01f0a663ddc2c146cfb69c09ba2d28f1.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-160_jpg.rf.9b9c898fd7a32189c99b3ce4d4ac5e22.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-151_jpg.rf.67eb75d12ea076f05103ccc166450323.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-163_jpg.rf.332ed683c8b9647459d91dd7e8f4253e.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-152_jpg.rf.24e784c3eed3ca3b89edfe44901334f8.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-153_jpg.rf.6ac057205c939eb55413a0759fff0a32.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-157_jpg.rf.adc5c4b31cf89648761eada39d4a7b79.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-158_jpg.rf.be75fdd955dd0489bd02ed5f6075b2cc.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-165_jpg.rf.bfee3177bf4809bf0a1003b1b63b9d4e.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-167_jpg.rf.1bc9c32c9561c5c38f969194f0609d11.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4-166_jpg.rf.2fefe28297588b125130f67a36c85435.jpg (Unsupported request. `POST /dataset/shipping-containers-kktus/upload` does not exist or cannot be loaded due to missing permissions.)
# [ERR] /content/containers_labeled/train/images/Tips-and-tricks-on-how-to-park-a-yard-jockey-_mp4